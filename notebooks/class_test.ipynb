# %%
import os
root_path = os.getcwd().replace('notebooks', '')
os.chdir(root_path)

# %%
from bok import Bok

# %%
auth_key = "JRHFEWO69KNFTMMRJ1SO"
bok = Bok(auth_key = auth_key)

# %%
bok.get_statistic_list(idx = 1)
# Out:
# {'StatisticTableList': {'list_total_count': 993,
#   'row': [{'P_STAT_CODE': '*',
#     'STAT_CODE': '0000000001',
#     'STAT_NAME': '1. 통화/금융',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000002',
#     'STAT_NAME': '1.1. 통화/유동성',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000003',
#     'STAT_NAME': '1.1.1. 본원통화',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000003',
#     'STAT_CODE': '0000000004',
#     'STAT_NAME': '1.1.1.1. 본원통화 구성내역',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y004',
#     'STAT_NAME': '1.1.1.1.1. 본원통화 구성내역(평잔, 계절조정계열)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y002',
# ...
